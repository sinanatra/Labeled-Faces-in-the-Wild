# %%
import os
from fnmatch import fnmatch

root = 'lfw/'
pattern = "*.jpg"

f = open("dataset_2.csv", "w")
f.write("person;image\n")

for path, subdirs, files in os.walk(root):
    for file in files:
        print( path.replace('lfw/', '').replace('_', ' '), file)
        f.write(path.replace('lfw/', '').replace('_', ' ') + ';' + str(file) + '\n')

f.close()
# Out:
# German Khan German_Khan_0001.jpg
# Stefano Gabbana Stefano_Gabbana_0001.jpg
# Dragan Covic Dragan_Covic_0001.jpg
# Jeff Hornacek Jeff_Hornacek_0001.jpg
# Sureyya Ayhan Sureyya_Ayhan_0001.jpg
# Deb Santos Deb_Santos_0001.jpg
# Bob Newhart Bob_Newhart_0001.jpg
# Wang Hailan Wang_Hailan_0001.jpg
# Paul McNulty Paul_McNulty_0002.jpg
# Paul McNulty Paul_McNulty_0001.jpg
# Jimmy Iovine Jimmy_Iovine_0001.jpg
# Claudia Pechstein Claudia_Pechstein_0001.jpg
# Claudia Pechstein Claudia_Pechstein_0003.jpg
# Claudia Pechstein Claudia_Pechstein_0002.jpg
# Claudia Pechstein Claudia_Pechstein_0005.jpg
# Claudia Pechstein Claudia_Pechstein_0004.jpg
# Ranil Wickremasinghe Ranil_Wickremasinghe_0002.jpg
# Ranil Wickremasinghe Ranil_Wickremasinghe_0003.jpg
# Ranil Wickremasinghe Ranil_Wickremasinghe_0001.jpg
# Ben Chandler Ben_Chandler_0001.jpg
# Mark Komara Mark_Komara_0001.jpg
# Rand Beers Rand_Beers_0001.jpg
# Joanne Woodward Joanne_Woodward_0001.jpg
# John Bond John_Bond_0001.jpg
# ...
